# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Hi/Downloads/titanic.csv')

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df['name']="gpt"

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone name
# 0    man        True  NaN  Southampton    no  False  gpt
# ...

# %%
df['add_fare']=df['fare']+10

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone name  add_fare
# 0    man        True  NaN  Southampton    no  False  gpt   17.2500
# 1  woman       False    C    Cherbourg   yes  False  gpt   81.2833
# 2  woman       False  NaN  Southampton   yes   True  gpt   17.9250
# 3  woman       False    C  Southampton   yes  False  gpt   63.1000
# 4    man        True  NaN  Southampton    no   True  gpt   18.0500

# %%
df['age_catogary']=df['age'].apply(lambda x: "junior" if x > 30  else "sineor" )

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone name  add_fare  \
# 0    man        True  NaN  Southampton    no  False  gpt   17.2500
# 1  woman       False    C    Cherbourg   yes  False  gpt   81.2833
# 2  woman       False  NaN  Southampton   yes   True  gpt   17.9250
# 3  woman       False    C  Southampton   yes  False  gpt   63.1000
# 4    man        True  NaN  Southampton    no   True  gpt   18.0500
#
#   age_catogary
# 0       sineor
# 1       junior
# 2       sineor
# 3       junior
# 4       junior

# %%
df['survived']=df['survived'].apply(lambda x: "no" if x==1 else "yes")

# %%
df.head(4)
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0      yes       3    male  22.0      1      0   7.2500        S  Third
# 1       no       1  female  38.0      1      0  71.2833        C  First
# 2       no       3  female  26.0      0      0   7.9250        S  Third
# 3       no       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone name  add_fare  \
# 0    man        True  NaN  Southampton    no  False  gpt   17.2500
# 1  woman       False    C    Cherbourg   yes  False  gpt   81.2833
# 2  woman       False  NaN  Southampton   yes   True  gpt   17.9250
# 3  woman       False    C  Southampton   yes  False  gpt   63.1000
#
#   age_catogary
# 0       sineor
# 1       junior
# 2       sineor
# 3       junior

# %%
df.drop('age_catogary',axis=1)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0        yes       3    male  22.0      1      0   7.2500        S   Third
# 1         no       1  female  38.0      1      0  71.2833        C   First
# 2         no       3  female  26.0      0      0   7.9250        S   Third
# 3         no       1  female  35.0      1      0  53.1000        S   First
# 4        yes       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886      yes       2    male  27.0      0      0  13.0000        S  Second
# 887       no       1  female  19.0      0      0  30.0000        S   First
# 888      yes       3  female   NaN      1      2  23.4500        S   Third
# 889       no       1    male  26.0      0      0  30.0000        C   First
# 890      yes       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone name  add_fare
# ...

# %%
df.drop(['name','add_fare'],axis=1)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0        yes       3    male  22.0      1      0   7.2500        S   Third
# 1         no       1  female  38.0      1      0  71.2833        C   First
# 2         no       3  female  26.0      0      0   7.9250        S   Third
# 3         no       1  female  35.0      1      0  53.1000        S   First
# 4        yes       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886      yes       2    male  27.0      0      0  13.0000        S  Second
# 887       no       1  female  19.0      0      0  30.0000        S   First
# 888      yes       3  female   NaN      1      2  23.4500        S   Third
# 889       no       1    male  26.0      0      0  30.0000        C   First
# 890      yes       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_catogary
# ...

# %%
df.drop(['name','add_fare'],axis=1,inplace=True)

# %%
df.head(4)
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0      yes       3    male  22.0      1      0   7.2500        S  Third
# 1       no       1  female  38.0      1      0  71.2833        C  First
# 2       no       3  female  26.0      0      0   7.9250        S  Third
# 3       no       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone age_catogary
# 0    man        True  NaN  Southampton    no  False       sineor
# 1  woman       False    C    Cherbourg   yes  False       junior
# 2  woman       False  NaN  Southampton   yes   True       sineor
# 3  woman       False    C  Southampton   yes  False       junior

# %%
df.drop(['sibsp','parch','fare','embarked','class','who','adult_male','deck','embark_town','alive','alone','age_catogary'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#   survived  pclass     sex   age
# 0      yes       3    male  22.0
# 1       no       1  female  38.0
# 2       no       3  female  26.0
# 3       no       1  female  35.0
# 4      yes       3    male  35.0

# %%
df.loc[len(df)]=[3,"no","mn",60]

# %%
df
# Out:
#     survived pclass     sex   age
# 0        yes      3    male  22.0
# 1         no      1  female  38.0
# 2         no      3  female  26.0
# 3         no      1  female  35.0
# 4        yes      3    male  35.0
# ..       ...    ...     ...   ...
# 887       no      1  female  19.0
# 888      yes      3  female   NaN
# 889       no      1    male  26.0
# 890      yes      3    male  32.0
# 891        3     no      mn  60.0
#
# [892 rows x 4 columns]

# %%
df.loc[(8)(df)]=[56,"uo","jk",70]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc[(8)(df)]=[56,"uo","jk",70]
#
# TypeError: 'int' object is not callable

# %%
df

# %%
df.drop(index=8,inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop([3,7,9])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            176
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           684
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df=df[df['age'].notna()]

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           527
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
v=df['sex'].value_counts()

# %%
v
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
v.plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
v.plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
v.plot(kind="line")
# Out:
# <Axes: xlabel='sex'>

# %%
m=df.groupby(['pclass','sex']).size().unstack()
m
# Out:
# sex     female  male
# pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
m.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
f=df[['pclass','sex']].value_counts()
f
# Out:
# pclass  sex
# 3       male      347
#         female    144
# 1       male      122
# 2       male      108
# 1       female     94
# 2       female     76
# Name: count, dtype: int64

# %%
m.plot(kind="line")
# Out:
# <Axes: xlabel='pclass'>

# %%
f.plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 m.plot(kind="pie")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:981, in PlotAccessor.__call__(self, *args, **kwargs)
#     979 if isinstance(data, ABCDataFrame):
#     980     if y is None and kwargs.get("subplots") is False:
# --> 981         raise ValueError(
#     982             f"{kind} requires either y column or 'subplots=True'"
#     983         )
#     984     if y is not None:
#     985         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
r=df.groupby(['pclass','sex','survived']).size().unstack()
r
# Out:
# survived         0   1
# pclass sex
# 1      female    3  91
#        male     77  45
# 2      female    6  70
#        male     91  17
# 3      female   72  72
#        male    300  47

# %%
r.plot(kind="bar")
# Out:
# <Axes: xlabel='pclass,sex'>

# %%
o=df.groupby(['pclass','sex','survived']).size().unstack()
o
