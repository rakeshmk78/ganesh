# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Hi/Downloads/data_season.csv')

# %%
df.head(4)
# Out:
#    Year   Location   Area  Rainfall  Temperature Soil type Irrigation  \
# 0  2004  Mangalore   1279    2903.1         27.0  Alluvial       Drip
# 1  2004  Mangalore  13283    2903.1         27.0  Alluvial       Drip
# 2  2004  Mangalore  52119    2903.1         27.0  Alluvial       Drip
# 3  2004  Mangalore    725    2996.6         27.0  Alluvial       Drip
#
#      yeilds  Humidity    Crops   price  Season
# 0    2570.0      57.0  Coconut  200000  Kharif
# 1   27170.0      57.5  Coconut    4847  Kharif
# 2  114744.0      57.0  Coconut   51239  Kharif
# 3    1402.0      55.0  Coconut  216396  Kharif

# %%
df.tail(4)
# Out:
#       Year   Location   Area  Rainfall  Temperature Soil type Irrigation  \
# 3154  2014  Davangere    103    3296.0         27.0       NaN       Drip
# 3155  2015  Davangere   8239    3550.0         27.0       NaN       Drip
# 3156  2016  Davangere  44563    3550.0         27.0       NaN       Drip
# 3157  2017  Davangere     96    3550.0         27.0       NaN       Drip
#
#         yeilds  Humidity    Crops   price Season
# 3154    1132.0      52.5  Coconut  216396   Rabi
# 3155   23960.0      56.0  Coconut    2644   Rabi
# 3156  126487.0      57.0  Coconut   44235   Rabi
# 3157     804.0      57.5  Coconut  203317   Rabi

# %% [markdown]
# # DataFrame ploting

# %% [markdown]
# ## Bar graph

# %%
m= df.groupby(['Crops','Location']).size().unstack()
m
# Out:
# Location   Bangalore  Chikmangaluru  Davangere  Gulbarga  Hassan  Kasaragodu  \
# Crops
# Arecanut         NaN           20.0        NaN      15.0    32.0        15.0
# Blackgram        NaN           28.0       15.0      15.0    47.0        15.0
# Cardamum         NaN            NaN        NaN      25.0    29.0         2.0
# Cashew           NaN           11.0       15.0      22.0    42.0         3.0
# Cocoa            NaN            1.0        NaN      18.0    17.0         6.0
# Coconut          NaN          146.0        9.0     268.0   352.0       101.0
# Coffee           NaN            NaN        NaN      32.0    21.0         NaN
# Cotton           NaN           11.0        NaN       4.0     1.0         NaN
# Ginger           NaN           36.0        NaN      49.0    80.0        29.0
# Groundnut       12.0           26.0        3.0      15.0    45.0        23.0
# Paddy            4.0           23.0        NaN      15.0    55.0        15.0
# ...

# %%
counts = df['Location'].value_counts()
counts
# Out:
# Location
# Hassan           798
# Gulbarga         504
# Mangalore        342
# Chikmangaluru    340
# Madikeri         240
# Raichur          231
# Kasaragodu       231
# Mysuru           222
# Kodagu           192
# Davangere         42
# Bangalore         16
# Name: count, dtype: int64

# %%
counts.plot(kind="bar")
# Out:
# <Axes: xlabel='Location'>

# %%
m.plot(kind="bar")
# Out:
# <Axes: xlabel='Crops'>
